# %%
import numpy as np
import math
# %matplotlib notebook
import matplotlib.pyplot as plt

# %% [markdown]
# ### Part A

# %%
n = 2 * np.random.randint(10, 25 + 1) + 1
origin = n // 2

crumb = np.random.randint(0, n)
while crumb == origin:
    crumb = np.random.randint(0, n)
    
log = np.zeros(n)
log[crumb] = 1
optimal_distance = abs(crumb - origin)

# %%
found_crumb = False
origin_relative_location = 0
distance_traveled = 0

while not found_crumb:
    
    origin_relative_location += 1

    if origin + origin_relative_location == crumb:
        
        found_crumb = True
        
        distance_traveled += origin_relative_location
        
    if origin - origin_relative_location == crumb:
        
        found_crumb = True
        
        distance_traveled += 2 * origin_relative_location
    
    if not found_crumb:
        distance_traveled += origin_relative_location

# %%
distance_traveled
# Out:
# 2

# %%
optimal_distance * 8
# Out:
# 8

# %%
optimal_distance
# Out:
# 1

# %%
13 * 8
# Out:
# 104

# %%
lower = [sum(2 ** k for k in range(1, math.ceil(math.log2(d)) + 1)) + d for d in range(1, 1000 + 1)]
upper = [sum(2 ** k for k in range(1, math.ceil(math.log2(d)) + 2)) + d for d in range(1, 1000 + 1)]

# %%
#plt.plot(range(len(lower)), lower)
plt.plot(range(len(upper)), upper)
plt.plot(range(1000), [9*d - 2 for d in range(1000)])
plt.plot(range(1000), [5*d - 2 for d in range(1000)])
# Out:
# <img src="data:image/png;base64,..." width="640">
